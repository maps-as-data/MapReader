# %% [markdown]
# # How to annotate patches on a map sheet.
#
# In this example, we will download one sheet — WFS ID 439, and start annotating it.

# %% [markdown]
# ## Import all necessary components of MapReader

# %%
from mapreader import SheetDownloader, loader

# %% [markdown]
# ## Define parameters and query for SheetDownloader

# %%
my_ts = SheetDownloader(
    metadata_path="../geospatial/NLS_metadata/metadata_OS_One_Inch_GB_WFS_light.json",
    download_url="https://mapseries-tilesets.s3.amazonaws.com/1inch_2nd_ed/{z}/{x}/{y}.png",
)

my_ts.query_map_sheets_by_wfs_ids(439)
# Out:
# [INFO] Metadata file has 480 item(s).

# %%
# Set zoom level
my_ts.get_grid_bb()

# %% [markdown]
# ## Download!

# %%
# Download
my_ts.download_map_sheets_by_queries(path_save="./download/maps")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# [INFO] "./download/maps/map_101169023.png" already exists. Skipping download.

# %% [markdown]
# ## Patchify!

# %%
# First load all the files
my_files = loader("./download/maps/*.png")
my_files.add_metadata(metadata="./download/maps/metadata.csv")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Then patchify!
my_files.patchify_all(path_save="./download/patches")
# Out:
# [INFO] Saving patches in directory named "./download/patches".
#   0%|          | 0/1 [00:00<?, ?it/s]
# download/maps/map_101169023.png

# %%
parent_df, patch_df = my_files.convert_images(save=True)
# Out:
# [INFO] Saved parent dataframe as "parent_df.csv"
# [INFO] Saved patch dataframe as "patch_df.csv"

# %%
patch_df.head()
# Out:
#                                                      parent_id  \
# image_id
# patch-0-0-100-100-#map_101169023.png#.png    map_101169023.png
# patch-0-100-100-200-#map_101169023.png#.png  map_101169023.png
# patch-0-200-100-300-#map_101169023.png#.png  map_101169023.png
# patch-0-300-100-400-#map_101169023.png#.png  map_101169023.png
# patch-0-400-100-500-#map_101169023.png#.png  map_101169023.png
#
#                                                                                     image_path  \
# image_id
# patch-0-0-100-100-#map_101169023.png#.png    /Users/rwood/LwM/mapreader/MapReader/worked_ex...
# patch-0-100-100-200-#map_101169023.png#.png  /Users/rwood/LwM/mapreader/MapReader/worked_ex...
# patch-0-200-100-300-#map_101169023.png#.png  /Users/rwood/LwM/mapreader/MapReader/worked_ex...
# patch-0-300-100-400-#map_101169023.png#.png  /Users/rwood/LwM/mapreader/MapReader/worked_ex...
# patch-0-400-100-500-#map_101169023.png#.png  /Users/rwood/LwM/mapreader/MapReader/worked_ex...
#
#                                                      shape  \
# image_id
# patch-0-0-100-100-#map_101169023.png#.png    (100, 100, 4)
# patch-0-100-100-200-#map_101169023.png#.png  (100, 100, 4)
# patch-0-200-100-300-#map_101169023.png#.png  (100, 100, 4)
# patch-0-300-100-400-#map_101169023.png#.png  (100, 100, 4)
# patch-0-400-100-500-#map_101169023.png#.png  (100, 100, 4)
#
#                                                    pixel_bounds  \
# image_id
# patch-0-0-100-100-#map_101169023.png#.png      (0, 0, 100, 100)
# patch-0-100-100-200-#map_101169023.png#.png  (0, 100, 100, 200)
# patch-0-200-100-300-#map_101169023.png#.png  (0, 200, 100, 300)
# patch-0-300-100-400-#map_101169023.png#.png  (0, 300, 100, 400)
# patch-0-400-100-500-#map_101169023.png#.png  (0, 400, 100, 500)
#
#                                                                                    coordinates  \
# image_id
# patch-0-0-100-100-#map_101169023.png#.png    (-0.85693359375, 50.99451607323993, -0.8483505...
# patch-0-100-100-200-#map_101169023.png#.png  (-0.85693359375, 50.989103290620214, -0.848350...
# patch-0-200-100-300-#map_101169023.png#.png  (-0.85693359375, 50.9836905080005, -0.84835052...
# patch-0-300-100-400-#map_101169023.png#.png  (-0.85693359375, 50.978277725380785, -0.848350...
# patch-0-400-100-500-#map_101169023.png#.png  (-0.85693359375, 50.97286494276107, -0.8483505...
#
#                                                    crs  \
# image_id
# patch-0-0-100-100-#map_101169023.png#.png    EPSG:4326
# patch-0-100-100-200-#map_101169023.png#.png  EPSG:4326
# patch-0-200-100-300-#map_101169023.png#.png  EPSG:4326
# patch-0-300-100-400-#map_101169023.png#.png  EPSG:4326
# patch-0-400-100-500-#map_101169023.png#.png  EPSG:4326
#
#                                                                                        polygon
# image_id
# patch-0-0-100-100-#map_101169023.png#.png    POLYGON ((-0.8483505249023438 50.9945160732399...
# patch-0-100-100-200-#map_101169023.png#.png  POLYGON ((-0.8483505249023438 50.9891032906202...
# patch-0-200-100-300-#map_101169023.png#.png  POLYGON ((-0.8483505249023438 50.9836905080005...
# patch-0-300-100-400-#map_101169023.png#.png  POLYGON ((-0.8483505249023438 50.9782777253807...
# patch-0-400-100-500-#map_101169023.png#.png  POLYGON ((-0.8483505249023438 50.9728649427610...

# %% [markdown]
# ## Preview the map
#
# Let's have a quick look at our map.

# %%
my_files.show_parent("map_101169023.png", patch_border=False)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# [<Figure size 1000x1000 with 1 Axes>]

# %%
my_files.show_sample(num_samples=6)

# %% [markdown]
# ## Annotate patches
#
# Now, we're ready to annotate patches. Let's set up an `Annotator`:

# %%
from mapreader import Annotator

# %%
annotator = Annotator(
    patch_paths="./download/patches/*.png",
    parent_paths="./download/maps/*.png",
    metadata_path="./download/maps/metadata.csv",
    delimiter=",",
    labels=["label 1", "label 2"],
    username="rosie",
    sortby="mean_pixel_R",
    ascending=True,
)
# Out:
# [INFO] Loading patches from ./download/patches/*.png.
# [INFO] Loading parents from ./download/maps/*.png.
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1872 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# [INFO] Adding metadata from ./download/maps/metadata.csv.

# %%
annotator.annotate(resize_to=300)
# Out:
# HBox(children=(Button(button_style='info', description='label 1', layout=Layout(flex='1 1 0%', width='auto'), …
# VBox(children=(HBox(children=(Button(description='« previous', layout=Layout(flex='1 1 0%', width='auto'), sty…
# Output(layout=Layout(align_items='center', display='flex', flex_flow='column'))

# %% [markdown]
# As you're progressing through the patches to annotate them, you'll see a file in the `annotations` directory here:

# %%
from pathlib import Path

[str(x) for x in Path("./annotations/").glob("*.csv")]
# Out:
# ['annotations/task_#rosie#-4c1e9c0e5bc9f5f39a923350edc16547.csv']

# %% [markdown]
# You can also access the annotations as a DataFrame here in Jupyter:

# %%
annotator.get_labelled_data()
# Out:
#                                                      label  \
# image_id
# patch-0-100-100-200-#map_101169023.png#.png        label 2
# patch-0-200-100-300-#map_101169023.png#.png        label 1
# patch-0-400-100-500-#map_101169023.png#.png        label 1
# patch-0-700-100-800-#map_101169023.png#.png        label 1
# patch-0-1000-100-1100-#map_101169023.png#.png      label 2
# patch-0-1200-100-1300-#map_101169023.png#.png      label 2
# patch-0-1500-100-1600-#map_101169023.png#.png      label 1
# patch-0-1700-100-1800-#map_101169023.png#.png      label 1
# patch-0-1800-100-1900-#map_101169023.png#.png      label 2
# patch-0-2200-100-2300-#map_101169023.png#.png      label 1
# patch-0-3000-100-3100-#map_101169023.png#.png      label 2
# patch-400-3400-500-3500-#map_101169023.png#.png    label 2
# patch-700-900-800-1000-#map_101169023.png#.png     label 2
# patch-800-2900-900-3000-#map_101169023.png#.png    label 2
# patch-1300-1400-1400-1500-#map_101169023.png#.png  label 2
# patch-2300-1000-2400-1100-#map_101169023.png#.png  map_101169023.png
# patch-2400-2100-2500-2200-#map_101169023.png#.png  map_101169023.png
# patch-2400-3500-2500-3584-#map_101169023.png#.png  map_101169023.png
# patch-2500-700-2600-800-#map_101169023.png#.png    map_101169023.png
# patch-2900-3500-3000-3584-#map_101169023.png#.png  map_101169023.png
# patch-3900-1600-4000-1700-#map_101169023.png#.png  map_101169023.png
# patch-4100-1500-4200-1600-#map_101169023.png#.png  map_101169023.png
# patch-4300-2400-4400-2500-#map_101169023.png#.png  map_101169023.png
# patch-4600-1800-4700-1900-#map_101169023.png#.png  map_101169023.png
# patch-4700-2700-4800-2800-#map_101169023.png#.png  map_101169023.png
# patch-5100-3500-5120-3584-#map_101169023.png#.png  map_101169023.png
#
#                                                                pixel_bounds
# image_id
# patch-0-100-100-200-#map_101169023.png#.png              (0, 100, 100, 200)
# patch-0-200-100-300-#map_101169023.png#.png              (0, 200, 100, 300)
# patch-0-400-100-500-#map_101169023.png#.png              (0, 400, 100, 500)
# patch-0-700-100-800-#map_101169023.png#.png              (0, 700, 100, 800)
# patch-0-1000-100-1100-#map_101169023.png#.png          (0, 1000, 100, 1100)
# patch-0-1200-100-1300-#map_101169023.png#.png          (0, 1200, 100, 1300)
# patch-0-1500-100-1600-#map_101169023.png#.png          (0, 1500, 100, 1600)
# patch-0-1700-100-1800-#map_101169023.png#.png          (0, 1700, 100, 1800)
# patch-0-1800-100-1900-#map_101169023.png#.png          (0, 1800, 100, 1900)
# patch-0-2200-100-2300-#map_101169023.png#.png          (0, 2200, 100, 2300)
# patch-0-3000-100-3100-#map_101169023.png#.png          (0, 3000, 100, 3100)
# patch-400-3400-500-3500-#map_101169023.png#.png      (400, 3400, 500, 3500)
# patch-700-900-800-1000-#map_101169023.png#.png        (700, 900, 800, 1000)
# patch-800-2900-900-3000-#map_101169023.png#.png      (800, 2900, 900, 3000)
# patch-1300-1400-1400-1500-#map_101169023.png#.png  (1300, 1400, 1400, 1500)
# patch-1400-1400-1500-1500-#map_101169023.png#.png  (1400, 1400, 1500, 1500)
# patch-1700-0-1800-100-#map_101169023.png#.png          (1700, 0, 1800, 100)
# patch-1900-3200-2000-3300-#map_101169023.png#.png  (1900, 3200, 2000, 3300)
# patch-2000-2700-2100-2800-#map_101169023.png#.png  (2000, 2700, 2100, 2800)
# patch-2100-900-2200-1000-#map_101169023.png#.png    (2100, 900, 2200, 1000)
# patch-2300-1000-2400-1100-#map_101169023.png#.png  (2300, 1000, 2400, 1100)
# patch-2400-2100-2500-2200-#map_101169023.png#.png  (2400, 2100, 2500, 2200)
# patch-2400-3500-2500-3584-#map_101169023.png#.png  (2400, 3500, 2500, 3584)
# patch-2500-700-2600-800-#map_101169023.png#.png      (2500, 700, 2600, 800)
# patch-2900-3500-3000-3584-#map_101169023.png#.png  (2900, 3500, 3000, 3584)
# patch-3900-1600-4000-1700-#map_101169023.png#.png  (3900, 1600, 4000, 1700)
# patch-4100-1500-4200-1600-#map_101169023.png#.png  (4100, 1500, 4200, 1600)
# patch-4300-2400-4400-2500-#map_101169023.png#.png  (4300, 2400, 4400, 2500)
# patch-4600-1800-4700-1900-#map_101169023.png#.png  (4600, 1800, 4700, 1900)
# patch-4700-2700-4800-2800-#map_101169023.png#.png  (4700, 2700, 4800, 2800)
# patch-5100-3500-5120-3584-#map_101169023.png#.png  (5100, 3500, 5120, 3584)

# %% [markdown]
# If you'd like to see the context image, set ``show_context`` to ``True``.

# %%
annotator.annotate(show_context=True, resize_to=None)
# Out:
# HBox(children=(Button(button_style='info', description='label 1', layout=Layout(flex='1 1 0%', width='auto'), …
# VBox(children=(HBox(children=(Button(description='« previous', layout=Layout(flex='1 1 0%', width='auto'), sty…
# Output(layout=Layout(align_items='center', display='flex', flex_flow='column'))

# %% [markdown]
# Alternatively, we can use our patch and parent dataframes directly (i.e. instead of loading parents/patches from file paths).

# %%
annotator = Annotator(
    patch_df = patch_df,
    parent_df = parent_df,
    delimiter=",",
    labels=["label 1", "label 2"],
    username="rosie",
    show_context=False,
)
# Out:
# [INFO] Loading existing patch annotations.

# %%
annotator.annotate()
# Out:
# HBox(children=(Button(button_style='info', description='label 1', layout=Layout(flex='1 1 0%', width='auto'), …
# VBox(children=(HBox(children=(Button(description='« previous', layout=Layout(flex='1 1 0%', width='auto'), sty…
# Output(layout=Layout(align_items='center', display='flex', flex_flow='column'))

# %% [markdown]
# Or, since we saved these as CSV files, we can pass the path to the parent/patch CSVs.

# %%
annotator = Annotator(
    patch_df = "./patch_df.csv",
    parent_df = "./parent_df.csv",
    delimiter=",",
    labels=["label 1", "label 2"],
    username="new",
    show_context=False,
)

# %%
annotator.annotate()
# Out:
# HBox(children=(Button(button_style='info', description='label 1', layout=Layout(flex='1 1 0%', width='auto'), …
# VBox(children=(HBox(children=(Button(description='« previous', layout=Layout(flex='1 1 0%', width='auto'), sty…
# Output(layout=Layout(align_items='center', display='flex', flex_flow='column'))

# %%
annotator.get_labelled_data()
# Out:
#                                                      label  \
# image_id
# patch-0-100-100-200-#map_101169023.png#.png        label 2
# patch-0-200-100-300-#map_101169023.png#.png        label 1
# patch-0-400-100-500-#map_101169023.png#.png        label 1
# patch-0-700-100-800-#map_101169023.png#.png        label 1
# patch-0-1000-100-1100-#map_101169023.png#.png      label 2
# patch-0-1200-100-1300-#map_101169023.png#.png      label 2
# patch-0-1500-100-1600-#map_101169023.png#.png      label 1
# patch-0-1700-100-1800-#map_101169023.png#.png      label 1
# patch-0-1800-100-1900-#map_101169023.png#.png      label 2
# patch-0-2200-100-2300-#map_101169023.png#.png      label 1
# patch-0-3000-100-3100-#map_101169023.png#.png      label 2
# patch-400-3400-500-3500-#map_101169023.png#.png    label 2
# patch-700-900-800-1000-#map_101169023.png#.png     label 2
# patch-800-2900-900-3000-#map_101169023.png#.png    label 2
# patch-1300-1400-1400-1500-#map_101169023.png#.png  label 2
# patch-1400-1400-1500-1500-#map_101169023.png#.png  label 2
# patch-1700-0-1800-100-#map_101169023.png#.png      label 1
# patch-1900-3200-2000-3300-#map_101169023.png#.png  label 1
# patch-2000-2700-2100-2800-#map_101169023.png#.png  label 1
# patch-2100-900-2200-1000-#map_101169023.png#.png   label 1
# patch-2300-1000-2400-1100-#map_101169023.png#.png  label 1
# patch-2400-2100-2500-2200-#map_101169023.png#.png  label 1
# patch-2500-700-2600-800-#map_101169023.png#.png    map_101169023.png
# patch-2900-3500-3000-3584-#map_101169023.png#.png  map_101169023.png
# patch-3900-1600-4000-1700-#map_101169023.png#.png  map_101169023.png
# patch-4100-1500-4200-1600-#map_101169023.png#.png  map_101169023.png
# patch-4300-2400-4400-2500-#map_101169023.png#.png  map_101169023.png
# patch-4600-1800-4700-1900-#map_101169023.png#.png  map_101169023.png
# patch-4700-2700-4800-2800-#map_101169023.png#.png  map_101169023.png
# patch-5100-3500-5120-3584-#map_101169023.png#.png  map_101169023.png
#
#                                                                pixel_bounds
# image_id
# patch-0-100-100-200-#map_101169023.png#.png              (0, 100, 100, 200)
# patch-0-200-100-300-#map_101169023.png#.png              (0, 200, 100, 300)
# patch-0-400-100-500-#map_101169023.png#.png              (0, 400, 100, 500)
# patch-0-700-100-800-#map_101169023.png#.png              (0, 700, 100, 800)
# patch-0-1000-100-1100-#map_101169023.png#.png          (0, 1000, 100, 1100)
# patch-0-1200-100-1300-#map_101169023.png#.png          (0, 1200, 100, 1300)
# patch-0-1500-100-1600-#map_101169023.png#.png          (0, 1500, 100, 1600)
# patch-0-1700-100-1800-#map_101169023.png#.png          (0, 1700, 100, 1800)
# patch-0-1800-100-1900-#map_101169023.png#.png          (0, 1800, 100, 1900)
# patch-0-2200-100-2300-#map_101169023.png#.png          (0, 2200, 100, 2300)
# patch-0-3000-100-3100-#map_101169023.png#.png          (0, 3000, 100, 3100)
# patch-400-3400-500-3500-#map_101169023.png#.png      (400, 3400, 500, 3500)
# patch-700-900-800-1000-#map_101169023.png#.png        (700, 900, 800, 1000)
# patch-800-2900-900-3000-#map_101169023.png#.png      (800, 2900, 900, 3000)
# patch-1300-1400-1400-1500-#map_101169023.png#.png  (1300, 1400, 1400, 1500)
# patch-1400-1400-1500-1500-#map_101169023.png#.png  (1400, 1400, 1500, 1500)
# patch-1700-0-1800-100-#map_101169023.png#.png          (1700, 0, 1800, 100)
# patch-1900-3200-2000-3300-#map_101169023.png#.png  (1900, 3200, 2000, 3300)
# patch-2000-2700-2100-2800-#map_101169023.png#.png  (2000, 2700, 2100, 2800)
# patch-2100-900-2200-1000-#map_101169023.png#.png    (2100, 900, 2200, 1000)
# patch-2300-1000-2400-1100-#map_101169023.png#.png  (2300, 1000, 2400, 1100)
# patch-2400-2100-2500-2200-#map_101169023.png#.png  (2400, 2100, 2500, 2200)
# patch-2400-3500-2500-3584-#map_101169023.png#.png  (2400, 3500, 2500, 3584)
# patch-2500-700-2600-800-#map_101169023.png#.png      (2500, 700, 2600, 800)
# patch-2900-3500-3000-3584-#map_101169023.png#.png  (2900, 3500, 3000, 3584)
# patch-3900-1600-4000-1700-#map_101169023.png#.png  (3900, 1600, 4000, 1700)
# patch-4100-1500-4200-1600-#map_101169023.png#.png  (4100, 1500, 4200, 1600)
# patch-4300-2400-4400-2500-#map_101169023.png#.png  (4300, 2400, 4400, 2500)
# patch-4600-1800-4700-1900-#map_101169023.png#.png  (4600, 1800, 4700, 1900)
# patch-4700-2700-4800-2800-#map_101169023.png#.png  (4700, 2700, 4800, 2800)
# patch-5100-3500-5120-3584-#map_101169023.png#.png  (5100, 3500, 5120, 3584)
