# %% [markdown]
# # Train/fine-tune computer vision (CV) classifiers
#
# In this notebook, we use the annotated images (see, e.g., notebooks `001` and `002`) to train/fine-tune CV classifiers.

# %%
# solve issue with autocomplete
# %config Completer.use_jedi = False

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from mapreader import classifier
from mapreader import loadAnnotations
from mapreader import patchTorchDataset

import numpy as np

import torch
from torch import nn
import torchvision
from torchvision import transforms
from torchvision import models

# %% [markdown]
# ## Read annotations

# %%
annotated_images = loadAnnotations()

# %%
annotated_images.load("./annotations_phenotype_open_access/phenotype_test_#kasra#.csv", 
                      path2dir="./dataset/eg_slice_50_50")
# Out:
# * reading: ./annotations_phenotype_open_access/phenotype_test_#kasra#.csv
# * #rows: 99
# * label column name: label (you can change this later by .set_col_label(new_label) )
# * shuffle rows: Yes
# * update paths in 'image_id' column by inserting './dataset/eg_slice_50_50'
#
# ------------------------
# * Number of annotations: 99
#
# * First few rows:
#                                             image_id  label
# 0  C:\Users\ecorcoran\classification_phenotype_te...      1
# 1  C:\Users\ecorcoran\classification_phenotype_te...      1
# 2  C:\Users\ecorcoran\classification_phenotype_te...      1
# 3  C:\Users\ecorcoran\classification_phenotype_te...      1
# 4  C:\Users\ecorcoran\classification_phenotype_te...      2
# ...
#
# * Value counts (column: label):
# 1    68
# 2    31
# Name: label, dtype: int64
# ------------------------

# %%
annotated_images.annotations.columns.tolist()
# Out:
# ['image_id', 'label']

# %%
print(annotated_images)
# Out:
# ------------------------
# * Number of annotations: 99
#
# * First few rows:
#                                             image_id  label
# 0  C:\Users\ecorcoran\classification_phenotype_te...      1
# 1  C:\Users\ecorcoran\classification_phenotype_te...      1
# 2  C:\Users\ecorcoran\classification_phenotype_te...      1
# 3  C:\Users\ecorcoran\classification_phenotype_te...      1
# 4  C:\Users\ecorcoran\classification_phenotype_te...      2
# ...
#
# * Value counts (column: label):
# 1    68
# 2    31
# Name: label, dtype: int64
# ------------------------

# %%
# We need to shift these labels so that they start from 0:
annotated_images.adjust_labels(shiftby=-1)
# Out:
# --------------------
# [INFO] value counts before shift:
# 1    68
# 2    31
# Name: label, dtype: int64
# --------------------
# [INFO] value counts after shift:
# 0    68
# 1    31
# Name: label, dtype: int64
# --------------------

# %%
# show sample images for target label (tar_label)
annotated_images.show_image_labels(tar_label=1, num_sample=6)

# %%
# show an image based on its index 
annotated_images.show_image(indx=2)

# %% [markdown]
# ### Split annotations into train/val or train/val/test
#
# We use a stratified method for splitting the annotations, that is, each set contains approximately the same percentage of samples of each target label as the original set.

# %%
annotated_images.split_annotations(frac_train=0.8, 
                                   frac_val=0.2, 
                                   frac_test=0.0)
# Out:
# ---------------------
# * Split dataset into:
#     Train: 79
#     Valid: 20
#     Test : 0
# ---------------------

# %% [markdown]
# Dataframes for train, validation and test sets can be accessed via:
#
# ```python
# annotated_images.train
# annotated_images.val
# annotated_images.test
# ```

# %%
annotated_images.train["label"].value_counts()
# Out:
# 0    54
# 1    25
# Name: label, dtype: int64

# %%
annotated_images.val["label"].value_counts()
# Out:
# 0    14
# 1     6
# Name: label, dtype: int64

# %%
# annotated_images.test["label"].value_counts()

# %% [markdown]
# # Classifier

# %% [markdown]
# ## Dataset

# %% [markdown]
# Define transformations to be applied to images before being used in training or validation/inference.
#
# `patchTorchDataset` has some default transformations. However, it is possible to define your own transformations and pass them to `patchTorchDataset`:

# %%
# ------------------
# --- Transformation
# ------------------ 

# FOR INCEPTION
#resize2 = 299
# otherwise:
resize2 = 224

# mean and standard deviations of pixel intensities in 
# all the patches in 6", second edition maps
normalize_mean = 1 - np.array([0.82860442, 0.82515008, 0.77019864])
normalize_std = 1 - np.array([0.1025585, 0.10527616, 0.10039222])
# other options:
# normalize_mean = [0.485, 0.456, 0.406]
# normalize_std = [0.229, 0.224, 0.225]

data_transforms = {
    'train': transforms.Compose(
        [transforms.Resize(resize2),
         transforms.RandomApply([
             transforms.RandomHorizontalFlip(p=0.5),
             transforms.RandomVerticalFlip(p=0.5),
             ], p=0.5),
#         transforms.RandomApply([
#             transforms.GaussianBlur(21, sigma=(0.5, 5.0)),
#             ], p=0.25),
         transforms.RandomApply([
             #transforms.RandomPerspective(distortion_scale=0.5, p=0.5),
             transforms.Resize((50, 50)),
             ], p=0.25),
#          transforms.RandomApply([
#              transforms.RandomAffine(180, translate=None, scale=None, shear=20),
#              ], p=0.25),
        transforms.Resize((resize2, resize2)),
        transforms.ToTensor(),
        transforms.Normalize(normalize_mean, normalize_std)
        ]),
    'val': transforms.Compose(
        [transforms.Resize((resize2, resize2)),
        transforms.ToTensor(),
        transforms.Normalize(normalize_mean, normalize_std)
        ]),
}

# %% [markdown]
# Now, we can use these transformations to instantiate `patchTorchDataset`:

# %%
train_dataset = patchTorchDataset(annotated_images.train, 
                                  transform=data_transforms["train"])
valid_dataset = patchTorchDataset(annotated_images.val,   
                                  transform=data_transforms["val"])
# test_dataset  = patchTorchDataset(annotated_images.test,  
#                                   transform=data_transforms["val"])

# %% [markdown]
# ## Sampler

# %%
# -----------
# --- Sampler
# -----------
# We define a sampler as we have a highly imbalanced dataset
label_counts_dict = annotated_images.train["label"].value_counts().to_dict()

class_sample_count = []
for i in range(0, len(label_counts_dict)):
    class_sample_count.append(label_counts_dict[i])
    
weights = 1. / (torch.Tensor(class_sample_count)/1.)
weights = weights.double()
print(f"Weights: {weights}")

train_sampler = torch.utils.data.sampler.WeightedRandomSampler(
    weights[train_dataset.patchframe["label"].to_list()], 
    num_samples=len(train_dataset.patchframe))

valid_sampler = torch.utils.data.sampler.WeightedRandomSampler(
    weights[valid_dataset.patchframe["label"].to_list()], 
    num_samples=len(valid_dataset.patchframe))
# Out:
# Weights: tensor([0.0185, 0.0400], dtype=torch.float64)

# %% [markdown]
# ## Dataloader

# %%
myclassifier = classifier(device="default")
# myclassifier.load("./checkpoint_12.pkl")
# Out:
# [INFO] Device is set to cpu

# %%
batch_size = 8

# Add training dataset
myclassifier.add2dataloader(train_dataset, 
                            set_name="train", 
                            batch_size=batch_size, 
                            # shuffle can be False as annotations have already been shuffled
                            shuffle=False,
                            num_workers=0,
                            sampler=train_sampler
                           )

# Add validation dataset
myclassifier.add2dataloader(valid_dataset, 
                            set_name="val", 
                            batch_size=batch_size, 
                            shuffle=False, 
                            num_workers=0,
                            #sampler=valid_sampler
                           )
# Out:
# [INFO] added 'train' dataloader with 79 elements.
# [INFO] added 'val' dataloader with 20 elements.

# %%
myclassifier.print_classes_dl()
# Out:
# [INFO] labels:      [1, 0]

# %%
# set class names for plots
class_names = {0: "No", 
               1: "Plant"}
myclassifier.set_classnames(class_names)

# %%
myclassifier.print_classes_dl()
# Out:
# [INFO] labels:      [1, 0]
# [INFO] class-names: {0: 'No', 1: 'Plant'}

# %%
myclassifier.batch_info()
# Out:
# [INFO] dataset: train
# #samples:    79
# #batch size: 8
# #batches:    10

# %%
for bn in range(1, 3):
    myclassifier.show_sample(set_name="train", 
                             batch_number=bn, 
                             print_batch_info=False)

# %% [markdown]
# ## Load a (pretrained) PyTorch model and add it to `classifier`

# %% [markdown]
# Two methods to add a (pretrained) PyTorch model:
# 1. Define a model using `from torchvision import models`
# 2. Use `.initialize_model` method

# %% [markdown]
# ### Method 1: Define a model using `from torchvision import models`

# %%
# # Choose a model from the supported PyTorch models
# model_ft = models.resnet18(pretrained=True)

# # Add FC based on the number of classes
# num_ftrs = model_ft.fc.in_features
# model_ft.fc = nn.Linear(num_ftrs, myclassifier.num_classes)

# # Add the model to myclassifier
# myclassifier.add_model(model_ft)

# %%
# myclassifier.model_summary()

# %% [markdown]
# ### Method 2: use `.initialize_model`

# %%
myclassifier.del_model()

# %%
myclassifier.initialize_model("resnet18", 
                              pretrained=True, 
                              last_layer_num_classes="default",
                              add_model=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to C:\Users\ecorcoran/.cache\torch\checkpoints\resnet18-5c106cde.pth
# 100.0%
# [INFO] labels:      [1, 0]
# [INFO] class-names: {0: 'No', 1: 'Plant'}

# %%
myclassifier.model_summary(only_trainable=False)
# Out:
# ------------------------------------------------------------------------------------------
# |                                  modules |           parameters |                  dim
# ------------------------------------------------------------------------------------------
# |                             conv1.weight |                 9408 |        [64, 3, 7, 7] |
# |                               bn1.weight |                   64 |                 [64] |
# |                                 bn1.bias |                   64 |                 [64] |
# |                    layer1.0.conv1.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.0.bn1.weight |                   64 |                 [64] |
# |                        layer1.0.bn1.bias |                   64 |                 [64] |
# |                    layer1.0.conv2.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.0.bn2.weight |                   64 |                 [64] |
# |                        layer1.0.bn2.bias |                   64 |                 [64] |
# |                    layer1.1.conv1.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.1.bn1.weight |                   64 |                 [64] |
# |                        layer1.1.bn1.bias |                   64 |                 [64] |
# |                    layer1.1.conv2.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.1.bn2.weight |                   64 |                 [64] |
# |                        layer1.1.bn2.bias |                   64 |                 [64] |
# |                    layer2.0.conv1.weight |                73728 |      [128, 64, 3, 3] |
# |                      layer2.0.bn1.weight |                  128 |                [128] |
# |                        layer2.0.bn1.bias |                  128 |                [128] |
# |                    layer2.0.conv2.weight |               147456 |     [128, 128, 3, 3] |
# |                      layer2.0.bn2.weight |                  128 |                [128] |
# |                        layer2.0.bn2.bias |                  128 |                [128] |
# |             layer2.0.downsample.0.weight |                 8192 |      [128, 64, 1, 1] |
# |             layer2.0.downsample.1.weight |                  128 |                [128] |
# |               layer2.0.downsample.1.bias |                  128 |                [128] |
# |                    layer2.1.conv1.weight |               147456 |     [128, 128, 3, 3] |
# |                      layer2.1.bn1.weight |                  128 |                [128] |
# |                        layer2.1.bn1.bias |                  128 |                [128] |
# |                    layer2.1.conv2.weight |               147456 |     [128, 128, 3, 3] |
# |                      layer2.1.bn2.weight |                  128 |                [128] |
# |                        layer2.1.bn2.bias |                  128 |                [128] |
# |                    layer3.0.conv1.weight |               294912 |     [256, 128, 3, 3] |
# |                      layer3.0.bn1.weight |                  256 |                [256] |
# |                        layer3.0.bn1.bias |                  256 |                [256] |
# |                    layer3.0.conv2.weight |               589824 |     [256, 256, 3, 3] |
# |                      layer3.0.bn2.weight |                  256 |                [256] |
# |                        layer3.0.bn2.bias |                  256 |                [256] |
# |             layer3.0.downsample.0.weight |                32768 |     [256, 128, 1, 1] |
# |             layer3.0.downsample.1.weight |                  256 |                [256] |
# |               layer3.0.downsample.1.bias |                  256 |                [256] |
# |                    layer3.1.conv1.weight |               589824 |     [256, 256, 3, 3] |
# |                      layer3.1.bn1.weight |                  256 |                [256] |
# |                        layer3.1.bn1.bias |                  256 |                [256] |
# |                    layer3.1.conv2.weight |               589824 |     [256, 256, 3, 3] |
# |                      layer3.1.bn2.weight |                  256 |                [256] |
# |                        layer3.1.bn2.bias |                  256 |                [256] |
# |                    layer4.0.conv1.weight |              1179648 |     [512, 256, 3, 3] |
# |                      layer4.0.bn1.weight |                  512 |                [512] |
# |                        layer4.0.bn1.bias |                  512 |                [512] |
# |                    layer4.0.conv2.weight |              2359296 |     [512, 512, 3, 3] |
# |                      layer4.0.bn2.weight |                  512 |                [512] |
# |                        layer4.0.bn2.bias |                  512 |                [512] |
# |             layer4.0.downsample.0.weight |               131072 |     [512, 256, 1, 1] |
# |             layer4.0.downsample.1.weight |                  512 |                [512] |
# |               layer4.0.downsample.1.bias |                  512 |                [512] |
# |                    layer4.1.conv1.weight |              2359296 |     [512, 512, 3, 3] |
# |                      layer4.1.bn1.weight |                  512 |                [512] |
# |                        layer4.1.bn1.bias |                  512 |                [512] |
# |                    layer4.1.conv2.weight |              2359296 |     [512, 512, 3, 3] |
# |                      layer4.1.bn2.weight |                  512 |                [512] |
# |                        layer4.1.bn2.bias |                  512 |                [512] |
# |                                fc.weight |                 1024 |             [2, 512] |
# |                                  fc.bias |                    2 |                  [2] |
# ------------------------------------------------------------------------------------------
# |                             Total params |             11177538 |                      |
# |                   Total trainable params |             11177538 |                      |
# ------------------------------------------------------------------------------------------
# | Other parameters:                                                                      |
# | * input size:   224                                                                    |
# | * is_inception: False                                                                  |
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## (Un)freeze layers in the neural network architecture

# %%
# myclassifier.freeze_layers(["conv1.weight", "bn1.weight", "bn1.bias", "layer1*", "layer2*", "layer3*"])
# myclassifier.model_summary(only_trainable=False)

# %%
# myclassifier.unfreeze_layers(["layer3*"])
# myclassifier.model_summary(only_trainable=False)

# %%
# myclassifier.only_keep_layers(["fc.weight", "fc.bias"])
# myclassifier.model_summary(only_trainable=True)

# %% [markdown]
# ## Define optimizer, scheduler and criterion

# %% [markdown]
# We can either use one learning rate for all the layers in the neural network or define layerwise learning rates, that is, the learning rate of each layer is different. This is normally used in fine-tuning pretrained models in which a smaller learning rate is assigned to the first layers.
#
# `MapReader` has a `.layerwise_lr` method to define layerwise learning rates. By default, `MapReader` uses a linear function to distribute the learning rates (using `min_lr` for the first layer and `max_lr` for the last layer). The linear function can be changed using `ltype="geomspace"` argument.

# %%
list2optim = myclassifier.layerwise_lr(min_lr=1e-4, max_lr=1e-3)
# #list2optim = myclassifier.layerwise_lr(min_lr=1e-4, max_lr=1e-3, ltype="geomspace")

# %%
optim_param_dict = {
    "lr": 1e-3,
    "betas": (0.9, 0.999), 
    "eps": 1e-08, 
    "weight_decay": 0, 
    "amsgrad": False
}

# --- if list2optim is defined, e.g., by using `.layerwise_lr` method (see the previous cell):
myclassifier.initialize_optimizer(optim_type="adam", 
                                  params2optim=list2optim,
                                  optim_param_dict=optim_param_dict,
                                  add_optim=True)

# --- otherwise:
# myclassifier.initialize_optimizer(optim_type="adam", 
#                                   optim_param_dict=optim_param_dict,
#                                   add_optim=True)

# %% [markdown]
# Other optimizers can also be used in the above cell, e.g.:
#
# ```python
# optim_param_dict = {
#     "lr": 1e-3,
#     "momentum": 0,
#     "dampening": 0,
#     "weight_decay": 0,
#     "nesterov": False
# }
#
# myclassifier.initialize_optimizer(optim_type="sgd",
#                                   optim_param_dict=optim_param_dict,
#                                   add_optim=True)
# ```

# %%
scheduler_param_dict = {
    "step_size": 10, 
    "gamma": 0.1, 
    "last_epoch": -1, 
#    "verbose": False
}

myclassifier.initialize_scheduler(scheduler_type="steplr",
                                  scheduler_param_dict=scheduler_param_dict,
                                  add_scheduler=True)

# %% [markdown]
# Other schedulers can also be used in the above cell, e.g.:
#
# ```python
# scheduler_param_dict = {
#     "max_lr": 1e-2,
#     "steps_per_epoch": len(myclassifier.dataloader["train"]),
#     "epochs": 5
# }
#
# myclassifier.initialize_scheduler(scheduler_type="OneCycleLR",
#                                   scheduler_param_dict=scheduler_param_dict,
#                                   add_scheduler=True)
# ```

# %%
# Add criterion
criterion = nn.CrossEntropyLoss()

myclassifier.add_criterion(criterion)

# %% [markdown]
# ## Train/fine-tune a model

# %%
myclassifier.train_component_summary()
# Out:
# ====================
# * Optimizer:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0001
#     lr: 0.0001
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00011475409836065574
#     lr: 0.00011475409836065574
#     weight_decay: 0
#
# Parameter Group 2
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0001295081967213115
#     lr: 0.0001295081967213115
#     weight_decay: 0
#
# Parameter Group 3
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00014426229508196722
#     lr: 0.00014426229508196722
#     weight_decay: 0
#
# Parameter Group 4
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00015901639344262296
#     lr: 0.00015901639344262296
#     weight_decay: 0
#
# Parameter Group 5
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0001737704918032787
#     lr: 0.0001737704918032787
#     weight_decay: 0
#
# Parameter Group 6
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00018852459016393443
#     lr: 0.00018852459016393443
#     weight_decay: 0
#
# Parameter Group 7
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00020327868852459017
#     lr: 0.00020327868852459017
#     weight_decay: 0
#
# Parameter Group 8
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0002180327868852459
#     lr: 0.0002180327868852459
#     weight_decay: 0
#
# Parameter Group 9
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00023278688524590167
#     lr: 0.00023278688524590167
#     weight_decay: 0
#
# Parameter Group 10
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0002475409836065574
#     lr: 0.0002475409836065574
#     weight_decay: 0
#
# Parameter Group 11
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00026229508196721314
#     lr: 0.00026229508196721314
#     weight_decay: 0
#
# Parameter Group 12
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00027704918032786887
#     lr: 0.00027704918032786887
#     weight_decay: 0
#
# Parameter Group 13
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0002918032786885246
#     lr: 0.0002918032786885246
#     weight_decay: 0
#
# Parameter Group 14
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00030655737704918034
#     lr: 0.00030655737704918034
#     weight_decay: 0
#
# Parameter Group 15
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0003213114754098361
#     lr: 0.0003213114754098361
#     weight_decay: 0
#
# Parameter Group 16
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0003360655737704918
#     lr: 0.0003360655737704918
#     weight_decay: 0
#
# Parameter Group 17
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00035081967213114755
#     lr: 0.00035081967213114755
#     weight_decay: 0
#
# Parameter Group 18
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0003655737704918033
#     lr: 0.0003655737704918033
#     weight_decay: 0
#
# Parameter Group 19
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.000380327868852459
#     lr: 0.000380327868852459
#     weight_decay: 0
#
# Parameter Group 20
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00039508196721311476
#     lr: 0.00039508196721311476
#     weight_decay: 0
#
# Parameter Group 21
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0004098360655737705
#     lr: 0.0004098360655737705
#     weight_decay: 0
#
# Parameter Group 22
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0004245901639344262
#     lr: 0.0004245901639344262
#     weight_decay: 0
#
# Parameter Group 23
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00043934426229508196
#     lr: 0.00043934426229508196
#     weight_decay: 0
#
# Parameter Group 24
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0004540983606557377
#     lr: 0.0004540983606557377
#     weight_decay: 0
#
# Parameter Group 25
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00046885245901639343
#     lr: 0.00046885245901639343
#     weight_decay: 0
#
# Parameter Group 26
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.00048360655737704917
#     lr: 0.00048360655737704917
#     weight_decay: 0
#
# Parameter Group 27
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0004983606557377049
#     lr: 0.0004983606557377049
#     weight_decay: 0
#
# Parameter Group 28
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0005131147540983606
#     lr: 0.0005131147540983606
#     weight_decay: 0
#
# Parameter Group 29
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0005278688524590164
#     lr: 0.0005278688524590164
#     weight_decay: 0
#
# Parameter Group 30
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0005426229508196721
#     lr: 0.0005426229508196721
#     weight_decay: 0
#
# Parameter Group 31
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0005573770491803278
#     lr: 0.0005573770491803278
#     weight_decay: 0
#
# Parameter Group 32
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0005721311475409836
#     lr: 0.0005721311475409836
#     weight_decay: 0
#
# Parameter Group 33
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0005868852459016393
#     lr: 0.0005868852459016393
#     weight_decay: 0
#
# Parameter Group 34
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0006016393442622952
#     lr: 0.0006016393442622952
#     weight_decay: 0
#
# Parameter Group 35
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0006163934426229509
#     lr: 0.0006163934426229509
#     weight_decay: 0
#
# Parameter Group 36
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0006311475409836066
#     lr: 0.0006311475409836066
#     weight_decay: 0
#
# Parameter Group 37
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0006459016393442624
#     lr: 0.0006459016393442624
#     weight_decay: 0
#
# Parameter Group 38
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0006606557377049181
#     lr: 0.0006606557377049181
#     weight_decay: 0
#
# Parameter Group 39
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0006754098360655738
#     lr: 0.0006754098360655738
#     weight_decay: 0
#
# Parameter Group 40
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0006901639344262296
#     lr: 0.0006901639344262296
#     weight_decay: 0
#
# Parameter Group 41
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0007049180327868853
#     lr: 0.0007049180327868853
#     weight_decay: 0
#
# Parameter Group 42
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.000719672131147541
#     lr: 0.000719672131147541
#     weight_decay: 0
#
# Parameter Group 43
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0007344262295081968
#     lr: 0.0007344262295081968
#     weight_decay: 0
#
# Parameter Group 44
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0007491803278688525
#     lr: 0.0007491803278688525
#     weight_decay: 0
#
# Parameter Group 45
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0007639344262295083
#     lr: 0.0007639344262295083
#     weight_decay: 0
#
# Parameter Group 46
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.000778688524590164
#     lr: 0.000778688524590164
#     weight_decay: 0
#
# Parameter Group 47
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0007934426229508197
#     lr: 0.0007934426229508197
#     weight_decay: 0
#
# Parameter Group 48
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0008081967213114755
#     lr: 0.0008081967213114755
#     weight_decay: 0
#
# Parameter Group 49
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0008229508196721312
#     lr: 0.0008229508196721312
#     weight_decay: 0
#
# Parameter Group 50
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0008377049180327869
#     lr: 0.0008377049180327869
#     weight_decay: 0
#
# Parameter Group 51
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0008524590163934427
#     lr: 0.0008524590163934427
#     weight_decay: 0
#
# Parameter Group 52
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0008672131147540984
#     lr: 0.0008672131147540984
#     weight_decay: 0
#
# Parameter Group 53
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0008819672131147541
#     lr: 0.0008819672131147541
#     weight_decay: 0
#
# Parameter Group 54
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0008967213114754099
#     lr: 0.0008967213114754099
#     weight_decay: 0
#
# Parameter Group 55
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0009114754098360656
#     lr: 0.0009114754098360656
#     weight_decay: 0
#
# Parameter Group 56
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0009262295081967213
#     lr: 0.0009262295081967213
#     weight_decay: 0
#
# Parameter Group 57
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0009409836065573771
#     lr: 0.0009409836065573771
#     weight_decay: 0
#
# Parameter Group 58
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0009557377049180328
#     lr: 0.0009557377049180328
#     weight_decay: 0
#
# Parameter Group 59
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0009704918032786885
#     lr: 0.0009704918032786885
#     weight_decay: 0
#
# Parameter Group 60
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0009852459016393442
#     lr: 0.0009852459016393442
#     weight_decay: 0
#
# Parameter Group 61
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.001
#     lr: 0.001
#     weight_decay: 0
# )
# ====================
# * Criterion:
# CrossEntropyLoss()
# ====================
# * Model:
# ------------------------------------------------------------------------------------------
# |                                  modules |           parameters |                  dim
# ------------------------------------------------------------------------------------------
# |                             conv1.weight |                 9408 |        [64, 3, 7, 7] |
# |                               bn1.weight |                   64 |                 [64] |
# |                                 bn1.bias |                   64 |                 [64] |
# |                    layer1.0.conv1.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.0.bn1.weight |                   64 |                 [64] |
# |                        layer1.0.bn1.bias |                   64 |                 [64] |
# |                    layer1.0.conv2.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.0.bn2.weight |                   64 |                 [64] |
# |                        layer1.0.bn2.bias |                   64 |                 [64] |
# |                    layer1.1.conv1.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.1.bn1.weight |                   64 |                 [64] |
# |                        layer1.1.bn1.bias |                   64 |                 [64] |
# |                    layer1.1.conv2.weight |                36864 |       [64, 64, 3, 3] |
# |                      layer1.1.bn2.weight |                   64 |                 [64] |
# |                        layer1.1.bn2.bias |                   64 |                 [64] |
# |                    layer2.0.conv1.weight |                73728 |      [128, 64, 3, 3] |
# |                      layer2.0.bn1.weight |                  128 |                [128] |
# |                        layer2.0.bn1.bias |                  128 |                [128] |
# |                    layer2.0.conv2.weight |               147456 |     [128, 128, 3, 3] |
# |                      layer2.0.bn2.weight |                  128 |                [128] |
# |                        layer2.0.bn2.bias |                  128 |                [128] |
# |             layer2.0.downsample.0.weight |                 8192 |      [128, 64, 1, 1] |
# |             layer2.0.downsample.1.weight |                  128 |                [128] |
# |               layer2.0.downsample.1.bias |                  128 |                [128] |
# |                    layer2.1.conv1.weight |               147456 |     [128, 128, 3, 3] |
# |                      layer2.1.bn1.weight |                  128 |                [128] |
# |                        layer2.1.bn1.bias |                  128 |                [128] |
# |                    layer2.1.conv2.weight |               147456 |     [128, 128, 3, 3] |
# |                      layer2.1.bn2.weight |                  128 |                [128] |
# |                        layer2.1.bn2.bias |                  128 |                [128] |
# |                    layer3.0.conv1.weight |               294912 |     [256, 128, 3, 3] |
# |                      layer3.0.bn1.weight |                  256 |                [256] |
# |                        layer3.0.bn1.bias |                  256 |                [256] |
# |                    layer3.0.conv2.weight |               589824 |     [256, 256, 3, 3] |
# |                      layer3.0.bn2.weight |                  256 |                [256] |
# |                        layer3.0.bn2.bias |                  256 |                [256] |
# |             layer3.0.downsample.0.weight |                32768 |     [256, 128, 1, 1] |
# |             layer3.0.downsample.1.weight |                  256 |                [256] |
# |               layer3.0.downsample.1.bias |                  256 |                [256] |
# |                    layer3.1.conv1.weight |               589824 |     [256, 256, 3, 3] |
# |                      layer3.1.bn1.weight |                  256 |                [256] |
# |                        layer3.1.bn1.bias |                  256 |                [256] |
# |                    layer3.1.conv2.weight |               589824 |     [256, 256, 3, 3] |
# |                      layer3.1.bn2.weight |                  256 |                [256] |
# |                        layer3.1.bn2.bias |                  256 |                [256] |
# |                    layer4.0.conv1.weight |              1179648 |     [512, 256, 3, 3] |
# |                      layer4.0.bn1.weight |                  512 |                [512] |
# |                        layer4.0.bn1.bias |                  512 |                [512] |
# |                    layer4.0.conv2.weight |              2359296 |     [512, 512, 3, 3] |
# |                      layer4.0.bn2.weight |                  512 |                [512] |
# |                        layer4.0.bn2.bias |                  512 |                [512] |
# |             layer4.0.downsample.0.weight |               131072 |     [512, 256, 1, 1] |
# |             layer4.0.downsample.1.weight |                  512 |                [512] |
# |               layer4.0.downsample.1.bias |                  512 |                [512] |
# |                    layer4.1.conv1.weight |              2359296 |     [512, 512, 3, 3] |
# |                      layer4.1.bn1.weight |                  512 |                [512] |
# |                        layer4.1.bn1.bias |                  512 |                [512] |
# |                    layer4.1.conv2.weight |              2359296 |     [512, 512, 3, 3] |
# |                      layer4.1.bn2.weight |                  512 |                [512] |
# |                        layer4.1.bn2.bias |                  512 |                [512] |
# |                                fc.weight |                 1024 |             [2, 512] |
# |                                  fc.bias |                    2 |                  [2] |
# ------------------------------------------------------------------------------------------
# |                   Total trainable params |             11177538 |                      |
# ------------------------------------------------------------------------------------------
# | Other parameters:                                                                      |
# | * input size:   224                                                                    |
# | * is_inception: False                                                                  |
# ------------------------------------------------------------------------------------------

# %% [markdown]
# **Note:** it is possible to interrupt a training (using Kernel/Interrupt in Jupyter Notebook or ctrl+C).

# %%
myclassifier.train(num_epochs=10, 
                   save_model_dir="./models_plant_open", 
                   tensorboard_path="tboard_plant_open", 
                   verbosity_level=0,
                   tmp_file_save_freq=2,
                   remove_after_load=False,
                   print_info_batch_freq=5)
# Out:
# 2022-01-14 15:54:17 AUTO-ATI04 [INFO] train    -- 1/10 --        8/79 ( 10.1%) -- Loss: 0.603
# 2022-01-14 15:54:24 AUTO-ATI04 [INFO] train    -- 1/10 --       48/79 ( 60.8%) -- Loss: 0.609
# 2022-01-14 15:54:29 AUTO-ATI04 [INFO] train    -- 1/10 -- Loss: 0.326; F_macro: 88.54; R_macro: 88.48
# 2022-01-14 15:54:29 AUTO-ATI04 [INFO] val      -- 1/10 --        8/20 ( 40.0%) -- Loss: 0.284
# 2022-01-14 15:54:30 AUTO-ATI04 [INFO] val      -- 1/10 -- Loss: 0.954; F_macro: 41.18; R_macro: 50.00
#
# 2022-01-14 15:54:31 AUTO-ATI04 [INFO] train    -- 2/10 --        8/79 ( 10.1%) -- Loss: 0.327
# 2022-01-14 15:54:39 AUTO-ATI04 [INFO] train    -- 2/10 --       48/79 ( 60.8%) -- Loss: 0.008
# 2022-01-14 15:54:44 AUTO-ATI04 [INFO] train    -- 2/10 -- Loss: 0.415; F_macro: 85.62; R_macro: 85.17
# 2022-01-14 15:54:45 AUTO-ATI04 [INFO] val      -- 2/10 --        8/20 ( 40.0%) -- Loss: 0.196
# 2022-01-14 15:54:46 AUTO-ATI04 [INFO] val      -- 2/10 -- Loss: 0.121; F_macro: 93.73; R_macro: 91.67
#
# SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 2
# [INFO] SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 2
#
# 2022-01-14 15:54:47 AUTO-ATI04 [INFO] train    -- 3/10 --        8/79 ( 10.1%) -- Loss: 0.006
# 2022-01-14 15:54:55 AUTO-ATI04 [INFO] train    -- 3/10 --       48/79 ( 60.8%) -- Loss: 0.057
# 2022-01-14 15:55:00 AUTO-ATI04 [INFO] train    -- 3/10 -- Loss: 0.219; F_macro: 91.05; R_macro: 91.50
# 2022-01-14 15:55:01 AUTO-ATI04 [INFO] val      -- 3/10 --        8/20 ( 40.0%) -- Loss: 0.134
# 2022-01-14 15:55:02 AUTO-ATI04 [INFO] val      -- 3/10 -- Loss: 0.106; F_macro: 100.00; R_macro: 100.00
#
# 2022-01-14 15:55:03 AUTO-ATI04 [INFO] train    -- 4/10 --        8/79 ( 10.1%) -- Loss: 0.123
# 2022-01-14 15:55:11 AUTO-ATI04 [INFO] train    -- 4/10 --       48/79 ( 60.8%) -- Loss: 0.054
# 2022-01-14 15:55:17 AUTO-ATI04 [INFO] train    -- 4/10 -- Loss: 0.087; F_macro: 98.73; R_macro: 98.72
# 2022-01-14 15:55:17 AUTO-ATI04 [INFO] val      -- 4/10 --        8/20 ( 40.0%) -- Loss: 0.039
# 2022-01-14 15:55:18 AUTO-ATI04 [INFO] val      -- 4/10 -- Loss: 0.035; F_macro: 100.00; R_macro: 100.00
#
# SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 4
# [INFO] SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 4
#
# 2022-01-14 15:55:20 AUTO-ATI04 [INFO] train    -- 5/10 --        8/79 ( 10.1%) -- Loss: 0.053
# 2022-01-14 15:55:28 AUTO-ATI04 [INFO] train    -- 5/10 --       48/79 ( 60.8%) -- Loss: 0.006
# 2022-01-14 15:55:33 AUTO-ATI04 [INFO] train    -- 5/10 -- Loss: 0.043; F_macro: 97.44; R_macro: 97.44
# 2022-01-14 15:55:34 AUTO-ATI04 [INFO] val      -- 5/10 --        8/20 ( 40.0%) -- Loss: 0.020
# 2022-01-14 15:55:35 AUTO-ATI04 [INFO] val      -- 5/10 -- Loss: 0.015; F_macro: 100.00; R_macro: 100.00
#
# 2022-01-14 15:55:36 AUTO-ATI04 [INFO] train    -- 6/10 --        8/79 ( 10.1%) -- Loss: 0.245
# 2022-01-14 15:55:44 AUTO-ATI04 [INFO] train    -- 6/10 --       48/79 ( 60.8%) -- Loss: 0.011
# 2022-01-14 15:55:51 AUTO-ATI04 [INFO] train    -- 6/10 -- Loss: 0.135; F_macro: 96.20; R_macro: 96.43
# 2022-01-14 15:55:51 AUTO-ATI04 [INFO] val      -- 6/10 --        8/20 ( 40.0%) -- Loss: 0.039
# 2022-01-14 15:55:52 AUTO-ATI04 [INFO] val      -- 6/10 -- Loss: 0.036; F_macro: 100.00; R_macro: 100.00
#
# SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 6
# [INFO] SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 6
#
# 2022-01-14 15:55:54 AUTO-ATI04 [INFO] train    -- 7/10 --        8/79 ( 10.1%) -- Loss: 0.037
# 2022-01-14 15:56:02 AUTO-ATI04 [INFO] train    -- 7/10 --       48/79 ( 60.8%) -- Loss: 0.015
# 2022-01-14 15:56:08 AUTO-ATI04 [INFO] train    -- 7/10 -- Loss: 0.046; F_macro: 98.72; R_macro: 98.86
# 2022-01-14 15:56:09 AUTO-ATI04 [INFO] val      -- 7/10 --        8/20 ( 40.0%) -- Loss: 0.046
# 2022-01-14 15:56:09 AUTO-ATI04 [INFO] val      -- 7/10 -- Loss: 0.040; F_macro: 100.00; R_macro: 100.00
#
# 2022-01-14 15:56:11 AUTO-ATI04 [INFO] train    -- 8/10 --        8/79 ( 10.1%) -- Loss: 0.039
# 2022-01-14 15:56:19 AUTO-ATI04 [INFO] train    -- 8/10 --       48/79 ( 60.8%) -- Loss: 0.020
# 2022-01-14 15:56:25 AUTO-ATI04 [INFO] train    -- 8/10 -- Loss: 0.034; F_macro: 100.00; R_macro: 100.00
# 2022-01-14 15:56:25 AUTO-ATI04 [INFO] val      -- 8/10 --        8/20 ( 40.0%) -- Loss: 0.015
# 2022-01-14 15:56:26 AUTO-ATI04 [INFO] val      -- 8/10 -- Loss: 0.014; F_macro: 100.00; R_macro: 100.00
#
# SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 8
# [INFO] SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 8
#
# 2022-01-14 15:56:28 AUTO-ATI04 [INFO] train    -- 9/10 --        8/79 ( 10.1%) -- Loss: 0.025
# 2022-01-14 15:56:37 AUTO-ATI04 [INFO] train    -- 9/10 --       48/79 ( 60.8%) -- Loss: 0.005
# 2022-01-14 15:56:44 AUTO-ATI04 [INFO] train    -- 9/10 -- Loss: 0.013; F_macro: 100.00; R_macro: 100.00
# 2022-01-14 15:56:44 AUTO-ATI04 [INFO] val      -- 9/10 --        8/20 ( 40.0%) -- Loss: 0.006
# 2022-01-14 15:56:45 AUTO-ATI04 [INFO] val      -- 9/10 -- Loss: 0.007; F_macro: 100.00; R_macro: 100.00
#
# 2022-01-14 15:56:47 AUTO-ATI04 [INFO] train    -- 10/10 --        8/79 ( 10.1%) -- Loss: 0.033
# 2022-01-14 15:56:55 AUTO-ATI04 [INFO] train    -- 10/10 --       48/79 ( 60.8%) -- Loss: 0.008
# 2022-01-14 15:57:02 AUTO-ATI04 [INFO] train    -- 10/10 -- Loss: 0.012; F_macro: 100.00; R_macro: 100.00
# 2022-01-14 15:57:02 AUTO-ATI04 [INFO] val      -- 10/10 --        8/20 ( 40.0%) -- Loss: 0.006
# 2022-01-14 15:57:03 AUTO-ATI04 [INFO] val      -- 10/10 -- Loss: 0.006; F_macro: 100.00; R_macro: 100.00
#
# SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 10
# [INFO] SAVE temp file: tmp_8830035262_checkpoint.pkl | set .last_epoch: 10
#
# Total time: 2m 48s
# [INFO] Save model epoch: 10 with least valid loss: 0.0065
# [INFO] Path: C:\Users\ecorcoran\classification_phenotype_test\models_plant_open\checkpoint_10.pkl

# %% [markdown]
# ### Plot results

# %%
list(myclassifier.metrics.keys())
# Out:
# ['epoch_loss_train',
#  'epoch_prec_micro_train',
#  'epoch_recall_micro_train',
#  'epoch_fscore_micro_train',
#  'epoch_supp_micro_train',
#  'epoch_rocauc_micro_train',
#  'epoch_prec_macro_train',
#  'epoch_recall_macro_train',
#  'epoch_fscore_macro_train',
#  'epoch_supp_macro_train',
#  'epoch_rocauc_macro_train',
#  'epoch_prec_weighted_train',
#  'epoch_recall_weighted_train',
#  'epoch_fscore_weighted_train',
#  'epoch_supp_weighted_train',
#  'epoch_rocauc_weighted_train',
#  'epoch_prec_0_train',
#  'epoch_recall_0_train',
#  'epoch_fscore_0_train',
#  'epoch_supp_0_train',
#  'epoch_prec_1_train',
#  'epoch_recall_1_train',
#  'epoch_fscore_1_train',
#  'epoch_supp_1_train',
#  'epoch_loss_val',
#  'epoch_prec_micro_val',
#  'epoch_recall_micro_val',
#  'epoch_fscore_micro_val',
#  'epoch_supp_micro_val',
#  'epoch_rocauc_micro_val',
#  'epoch_prec_macro_val',
#  'epoch_recall_macro_val',
#  'epoch_fscore_macro_val',
#  'epoch_supp_macro_val',
#  'epoch_rocauc_macro_val',
#  'epoch_prec_weighted_val',
#  'epoch_recall_weighted_val',
#  'epoch_fscore_weighted_val',
#  'epoch_supp_weighted_val',
#  'epoch_rocauc_weighted_val',
#  'epoch_prec_0_val',
#  'epoch_recall_0_val',
#  'epoch_fscore_0_val',
#  'epoch_supp_0_val',
#  'epoch_prec_1_val',
#  'epoch_recall_1_val',
#  'epoch_fscore_1_val',
#  'epoch_supp_1_val']

# %%
myclassifier.plot_metric(y_axis=["epoch_loss_train", "epoch_loss_val"],
                         y_label="Loss",
                         legends=["Train", "Valid"],
                         colors=["k", "tab:red"])

# %%
myclassifier.plot_metric(y_axis=["epoch_rocauc_macro_train", "epoch_rocauc_macro_val"],
                         y_label="ROC AUC",
                         legends=["Train", "Valid"],
                         colors=["k", "tab:red"])

# %%
myclassifier.plot_metric(y_axis=["epoch_fscore_macro_train", 
                                 "epoch_fscore_macro_val", 
                                 "epoch_fscore_0_val", 
                                 "epoch_fscore_1_val"],
                         y_label="F-score",
                         legends=["Train", 
                                  "Valid", 
                                  "Valid (label: 0)",
                                  "Valid (label: 1)",],
                         colors=["k", "tab:red", "tab:red", "tab:red"],
                         styles=["-", "-", "--", ":"],
                         markers=["o", "o", "", ""],
                         plt_yrange=[0, 100])

# %%
myclassifier.plot_metric(y_axis=["epoch_recall_macro_train", 
                                 "epoch_recall_macro_val", 
                                 "epoch_recall_0_val", 
                                 "epoch_recall_1_val"],
                         y_label="Recall",
                         legends=["Train", 
                                  "Valid", 
                                  "Valid (label: 0)",
                                  "Valid (label: 1)",],
                         colors=["k", "tab:red", "tab:red", "tab:red"],
                         styles=["-", "-", "--", ":"],
                         markers=["o", "o", "", ""],
                         plt_yrange=[0, 100])
