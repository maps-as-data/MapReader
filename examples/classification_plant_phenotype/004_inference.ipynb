# %% [markdown]
# # Model inference
#
# In the previous notebook, we saw how to do model inference on the test set. Here, we show how to load an already trained/fine-tuned model and a dataset and then do model inference.

# %%
# solve issue with autocomplete
# %config Completer.use_jedi = False

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from mapreader import loader
from mapreader import classifier
from mapreader import load_patches
from mapreader import patchTorchDataset

import glob
import matplotlib.pyplot as plt
import numpy as np
import os
##from scipy.interpolate import griddata
from torchvision import transforms

# %% [markdown]
# ## Read patches (i.e., sliced images) and add metadata
#
# First, we need to load a set of images/pathces. We use a CV model to do inference on these images.

# %%
myimgs = load_patches("./dataset/eg_slice_50_50/*PNG", 
                      parent_paths="./dataset/open_access_plant/*png")

# %%
imgs_pd, patches_pd = myimgs.convertImages(fmt="dataframe")
patches_pd.head()
# Out:
#                                                                       parent_id  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   2014-06-06_plant001_rgb.png
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   2014-07-17_plant047_rgb.png
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  2014-06-06_plant001_rgb.png
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  2014-07-17_plant047_rgb.png
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  2014-06-06_plant001_rgb.png
#
#                                                                                            image_path  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
#
#                                                     min_x  min_y  max_x  max_y
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG       0      0     50     50
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG       0      0     50     50
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...      0    100     50    150
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...      0    100     50    150
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...      0    150     50    200

# %% [markdown]
# In `.add_metadata`:
#
# ```python
# # remove duplicates using "name" column
# if columns == None:
#     columns = list(metadata_df.columns)
#
# if ("name" in columns) and ("image_id" in columns):
#     print(f"Both 'name' and 'image_id' columns exist! Use 'name' to index.")
#     image_id_col = "name"
# if "name" in columns:
#     image_id_col = "name"
# elif "image_id" in columns:
#     image_id_col = "image_id"
# else:
#     raise ValueError("'name' or 'image_id' should be one of the columns.")
# ```
#
# The dataframe should have either `name` or `image_id` column, and that column should be the image ID (NOT the path to the image).

# %%
# Rename image_path to image_id
# This is needed later (see `.add_metadata`)
patches_pd = patches_pd.reset_index()
patches_pd.rename(columns={"index": "image_id"}, 
                  inplace=True)
patches_pd.head()
# Out:
#                                             image_id  \
# 0  patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG
# 1  patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG
# 2  patch-0-100-50-150-#2014-06-06_plant001_rgb.pn...
# 3  patch-0-100-50-150-#2014-07-17_plant047_rgb.pn...
# 4  patch-0-150-50-200-#2014-06-06_plant001_rgb.pn...
#
#                      parent_id  \
# 0  2014-06-06_plant001_rgb.png
# 1  2014-07-17_plant047_rgb.png
# 2  2014-06-06_plant001_rgb.png
# 3  2014-07-17_plant047_rgb.png
# 4  2014-06-06_plant001_rgb.png
#
#                                           image_path  min_x  min_y  max_x  \
# 0  C:\Users\ecorcoran\classification_phenotype_te...      0      0     50
# 1  C:\Users\ecorcoran\classification_phenotype_te...      0      0     50
# 2  C:\Users\ecorcoran\classification_phenotype_te...      0    100     50
# 3  C:\Users\ecorcoran\classification_phenotype_te...      0    100     50
# 4  C:\Users\ecorcoran\classification_phenotype_te...      0    150     50
#
#    max_y
# 0     50
# 1     50
# 2    150
# 3    150
# 4    200

# %%
patches2infer = patches_pd[["image_path"]]
patches2infer
# Out:
#                                             image_path
# 0    C:\Users\ecorcoran\classification_phenotype_te...
# 1    C:\Users\ecorcoran\classification_phenotype_te...
# 2    C:\Users\ecorcoran\classification_phenotype_te...
# 3    C:\Users\ecorcoran\classification_phenotype_te...
# 4    C:\Users\ecorcoran\classification_phenotype_te...
# ..                                                 ...
# 215  C:\Users\ecorcoran\classification_phenotype_te...
# 216  C:\Users\ecorcoran\classification_phenotype_te...
# 217  C:\Users\ecorcoran\classification_phenotype_te...
# 218  C:\Users\ecorcoran\classification_phenotype_te...
# 219  C:\Users\ecorcoran\classification_phenotype_te...
#
# [220 rows x 1 columns]

# %% [markdown]
# ## Add patches to `patchTorchDataset`

# %%
# ------------------
# --- Transformation
# ------------------
# FOR INCEPTION
#resize2 = 299
# otherwise:
resize2 = 224

# mean and standard deviations of pixel intensities in 
# all the patches in 6", second edition maps
normalize_mean = 1 - np.array([0.82860442, 0.82515008, 0.77019864])
normalize_std = 1 - np.array([0.1025585, 0.10527616, 0.10039222])
# other options:
# normalize_mean = [0.485, 0.456, 0.406]
# normalize_std = [0.229, 0.224, 0.225]

data_transforms = {
    'val': transforms.Compose(
        [transforms.Resize((resize2, resize2)),
        transforms.ToTensor(),
        transforms.Normalize(normalize_mean, normalize_std)
        ]),
}

# %%
patches2infer_dataset = patchTorchDataset(patches2infer, 
                                          transform=data_transforms["val"])

# %% [markdown]
# ## Load a classifier (normally trained in notebook 003)

# %%
myclassifier = classifier(device="default")
myclassifier.load("./models_plant_open/checkpoint_10.pkl")
# Out:
# [INFO] Device is set to cpu

# %%
# Add dataset to myclassifier
batch_size=64
myclassifier.add2dataloader(patches2infer_dataset, 
                            set_name="infer_test", 
                            batch_size=batch_size, 
                            shuffle=False, 
                            num_workers=0)
# Out:
# [INFO] added 'infer_test' dataloader with 220 elements.

# %% [markdown]
# ## Inference on `set_name`

# %%
myclassifier.inference(set_name="infer_test")
# Out:
# 2022-01-14 16:03:10 AUTO-ATI04 [INFO] infer_test -- 11/11 --      64/220 ( 29.1%) --
# Total time: 0m 19s

# %% [markdown]
# ## Plot sample results

# %%
myclassifier.class_names
# Out:
# {0: 'No', 1: 'Plant'}

# %%
myclassifier.inference_sample_results(num_samples=8, 
                                      class_index=0, 
                                      set_name="infer_test",
                                      min_conf=50,
                                      max_conf=None)

# %% [markdown]
# ## Add model inference outputs to `myimgs`

# %%
patches2infer['pred'] = myclassifier.pred_label
patches2infer['conf'] = np.max(np.array(myclassifier.pred_conf), 
                               axis=1)
patches2infer
# Out:
#                                             image_path  pred      conf
# 0    C:\Users\ecorcoran\classification_phenotype_te...     0  0.984618
# 1    C:\Users\ecorcoran\classification_phenotype_te...     0  0.989366
# 2    C:\Users\ecorcoran\classification_phenotype_te...     0  0.998607
# 3    C:\Users\ecorcoran\classification_phenotype_te...     0  0.998475
# 4    C:\Users\ecorcoran\classification_phenotype_te...     0  0.998468
# ..                                                 ...   ...       ...
# 215  C:\Users\ecorcoran\classification_phenotype_te...     0  0.998389
# 216  C:\Users\ecorcoran\classification_phenotype_te...     0  0.998500
# 217  C:\Users\ecorcoran\classification_phenotype_te...     0  0.999183
# 218  C:\Users\ecorcoran\classification_phenotype_te...     0  0.998543
# 219  C:\Users\ecorcoran\classification_phenotype_te...     0  0.998440
#
# [220 rows x 3 columns]

# %%
patches_pd = \
    patches_pd.merge(patches2infer, 
                     how="outer",
                     on="image_path",
                     validate="1:1")

# %%
patches_pd.head()
# Out:
#                                             image_id  \
# 0  patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG
# 1  patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG
# 2  patch-0-100-50-150-#2014-06-06_plant001_rgb.pn...
# 3  patch-0-100-50-150-#2014-07-17_plant047_rgb.pn...
# 4  patch-0-150-50-200-#2014-06-06_plant001_rgb.pn...
#
#                      parent_id  \
# 0  2014-06-06_plant001_rgb.png
# 1  2014-07-17_plant047_rgb.png
# 2  2014-06-06_plant001_rgb.png
# 3  2014-07-17_plant047_rgb.png
# 4  2014-06-06_plant001_rgb.png
#
#                                           image_path  min_x  min_y  max_x  \
# 0  C:\Users\ecorcoran\classification_phenotype_te...      0      0     50
# 1  C:\Users\ecorcoran\classification_phenotype_te...      0      0     50
# 2  C:\Users\ecorcoran\classification_phenotype_te...      0    100     50
# 3  C:\Users\ecorcoran\classification_phenotype_te...      0    100     50
# 4  C:\Users\ecorcoran\classification_phenotype_te...      0    150     50
#
#    max_y  pred      conf
# 0     50     0  0.984618
# 1     50     0  0.989366
# 2    150     0  0.998607
# 3    150     0  0.998475
# 4    200     0  0.998468

# %%
myimgs.add_metadata(patches_pd, 
                    tree_level="child")

# %% [markdown]
# ## Write outputs as CSVs, one file per image

# %%
imgs_pd, patches_pd = myimgs.convertImages(fmt="dataframe")
patches_pd.head()
# Out:
#                                                                       parent_id  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   2014-06-06_plant001_rgb.png
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   2014-07-17_plant047_rgb.png
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  2014-06-06_plant001_rgb.png
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  2014-07-17_plant047_rgb.png
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  2014-06-06_plant001_rgb.png
#
#                                                                                            image_path  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
#
#                                                     min_x  min_y  max_x  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG       0      0     50
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG       0      0     50
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...      0    100     50
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...      0    100     50
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...      0    150     50
#
#                                                     max_y  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG      50
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG      50
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...    150
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...    150
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...    200
#
#                                                                                              image_id  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  patch-0-100-50-150-#2014-06-06_plant001_rgb.pn...
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  patch-0-100-50-150-#2014-07-17_plant047_rgb.pn...
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  patch-0-150-50-200-#2014-06-06_plant001_rgb.pn...
#
#                                                     pred      conf
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG      0  0.984618
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG      0  0.989366
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...     0  0.998607
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...     0  0.998475
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...     0  0.998468

# %%
imgs_pd["name"] = imgs_pd["image_path"].apply(lambda x: os.path.basename(x))

# %%
imgs_pd
# Out:
#                             parent_id  \
# 2014-06-06_plant001_rgb.png      None
# 2014-07-17_plant047_rgb.png      None
#
#                                                                     image_path  \
# 2014-06-06_plant001_rgb.png  C:\Users\ecorcoran\classification_phenotype_te...
# 2014-07-17_plant047_rgb.png  C:\Users\ecorcoran\classification_phenotype_te...
#
#                                                                       children  \
# 2014-06-06_plant001_rgb.png  [patch-0-0-50-50-#2014-06-06_plant001_rgb.png#...
# 2014-07-17_plant047_rgb.png  [patch-0-0-50-50-#2014-07-17_plant047_rgb.png#...
#
#                                                     name
# 2014-06-06_plant001_rgb.png  2014-06-06_plant001_rgb.png
# 2014-07-17_plant047_rgb.png  2014-07-17_plant047_rgb.png

# %%
output_dir = "./infer_output_open_plant"
os.makedirs(output_dir, exist_ok=True)

# %%
for one_img in list(imgs_pd.index):
    # --- paths
    img_name = one_img.split(".")[0]
    patch2write = os.path.join(output_dir, f"patch_{img_name}.csv")
    sheet2write = os.path.join(output_dir, f"sheet_{img_name}.csv")
    # --- write outputs
    patches_pd[patches_pd["parent_id"] == one_img].to_csv(patch2write, index=False)
    imgs_pd[imgs_pd.index == one_img].to_csv(sheet2write, index=False)

# %% [markdown]
# ## Load outputs and plot
#
# Although we already have all the required dataframes/variables loaded, we re-load them here as this is a required step in most realistic applications.

# %%
myimgs = load_patches("./dataset/eg_slice_50_50/*PNG", 
                      parent_paths="./dataset/open_access_plant/*png")

# %%
# load the CSV files which contain predictions/confidence/...
path2patch = glob.glob("./infer_output_open_plant/*csv")

for path2metadata in path2patch:
    print(path2metadata)
    myimgs.add_metadata(metadata=path2metadata, 
                        tree_level="child", 
                        delimiter=",")

# or directly:
# myimgs.add_metadata(patches_pd, tree_level="child")
# Out:
# ./infer_output_open_plant\patch_2014-06-06_plant001_rgb.csv
# ./infer_output_open_plant\patch_2014-07-17_plant047_rgb.csv
# ./infer_output_open_plant\sheet_2014-06-06_plant001_rgb.csv
# ./infer_output_open_plant\sheet_2014-07-17_plant047_rgb.csv

# %%
# List of all parents
all_parents = myimgs.list_parents()

myimgs.show_par(all_parents[1], 
                value="pred",
                border=None,
                plot_parent=True,
                vmin=0, vmax=1,
                figsize=(20, 20),
                alpha=0.5, 
                colorbar="inferno")

# %%
imgs_pd, patches_pd = myimgs.convertImages(fmt="dataframe")
print(len(patches_pd))
patches_pd.head()
# Out:
# 220
#                                                                       parent_id  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   2014-06-06_plant001_rgb.png
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   2014-07-17_plant047_rgb.png
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  2014-06-06_plant001_rgb.png
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  2014-07-17_plant047_rgb.png
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  2014-06-06_plant001_rgb.png
#
#                                                                                            image_path  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  C:\Users\ecorcoran\classification_phenotype_te...
#
#                                                     min_x  min_y  max_x  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG       0      0     50
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG       0      0     50
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...      0    100     50
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...      0    100     50
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...      0    150     50
#
#                                                     max_y  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG      50
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG      50
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...    150
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...    150
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...    200
#
#                                                                                              image_id  \
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG   patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG   patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...  patch-0-100-50-150-#2014-06-06_plant001_rgb.pn...
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...  patch-0-100-50-150-#2014-07-17_plant047_rgb.pn...
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...  patch-0-150-50-200-#2014-06-06_plant001_rgb.pn...
#
#                                                     pred      conf
# patch-0-0-50-50-#2014-06-06_plant001_rgb.png#.PNG      0  0.984618
# patch-0-0-50-50-#2014-07-17_plant047_rgb.png#.PNG      0  0.989366
# patch-0-100-50-150-#2014-06-06_plant001_rgb.png...     0  0.998607
# patch-0-100-50-150-#2014-07-17_plant047_rgb.png...     0  0.998475
# patch-0-150-50-200-#2014-06-06_plant001_rgb.png...     0  0.998468

# %%
# filter patches with NaNs
patches_filt = patches_pd[~patches_pd["pred"].isna()]
patches_filt = patches_pd[patches_pd["pred"] >= 0]
patches_filt["pred"].value_counts()
# Out:
# 0    158
# 1     62
# Name: pred, dtype: int64
